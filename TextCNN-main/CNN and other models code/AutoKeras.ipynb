# %%
'''In the contest of neural networks, AutoML searches among different neural network architectures
and hyperparameters to find the best fit, in a process called Neural Architecture Search¹ (NAS).

AutoKeras² is an open-source library that implements³ AutoML for deep learning using the Keras API.'''

# %%
# !pip install autokeras

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import autokeras as ak

# %%
# !wget "https://archive.ics.uci.edu/ml/machine-learning-databases/00228/smsspamcollection.zip"
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
fileName = 'C:/Users/HP/Desktop/SMSSpamCollection'
df = pd.DataFrame({'label':int(), 'text':str()}, index=[])
with open(fileName) as f:
    for line in f.readlines():
        split = line.split('\t')
        df = df.append({'label': 1 if split[0]=='spam' else 0,
                    'text': split[1]},
                   ignore_index = True)
df.head()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10084\937032998.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'label': 1 if split[0]=='spam' else 0,
# C:\Users\HP\AppData\Local\Temp\ipykernel_10084\937032998.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'label': 1 if split[0]=='spam' else 0,
# C:\Users\HP\AppData\Local\Temp\ipykernel_10084\937032998.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'label': 1 if split[0]=='spam' else 0,
# C:\Users\HP\AppData\Local\Temp\ipykernel_10084\937032998.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
from sklearn.model_selection import train_test_split
x = np.array(df.text)
y = np.array(df.label)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)

# %%
clf = ak.TextClassifier(max_trials=3)
clf.fit(x_train, y_train,epochs=1)
# Out:
# Trial 3 Complete [00h 18m 52s]
# val_loss: 0.027970295399427414
#
# Best val_loss So Far: 0.017043987289071083
# Total elapsed time: 00h 18m 52s
# INFO:tensorflow:Oracle triggered exit
# 131/131 [==============================] - 8s 45ms/step - loss: 0.4298 - accuracy: 0.8577
# INFO:tensorflow:Assets written to: .\text_classifier\best_model\assets

# %%
from sklearn.metrics import classification_report
y_hat = clf.predict(x_test)
print(classification_report(y_test, y_hat))
# Out:
# ...
# 44/44 [==============================] - 1s 15ms/step
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94      1234
#            1       0.00      0.00      0.00       160
#
#     accuracy                           0.89      1394
#    macro avg       0.44      0.50      0.47      1394
# weighted avg       0.78      0.89      0.83      1394
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
# get the best performing model
model = clf.export_model()
# display the architecture of the best performing model
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None,)]            0           []
#
#  expand_last_dim (ExpandLastDim  (None, 1)           0           ['input_1[0][0]']
#  )
#
#  text_vectorization (TextVector  (None, 200)         0           ['expand_last_dim[0][0]']
#  ization)
#
#  tf.compat.v1.shape (TFOpLambda  (2,)                0           ['text_vectorization[0][0]']
#  )
#
#  tf.__operators__.getitem (Slic  ()                  0           ['tf.compat.v1.shape[0][0]']
#  ingOpLambda)
#
#  tf.ones (TFOpLambda)           (None, 1)            0           ['tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  tf.linalg.matmul (TFOpLambda)  (None, 200)          0           ['tf.ones[0][0]']
#
# ...

# %%
from tensorflow.keras.models import load_model
# save the model on disk
model.save("text_classifier", save_format = "tf")
# load the model from disk
loaded_model = load_model("text_classifier",
                          custom_objects = ak.CUSTOM_OBJECTS)
# use loaded model for future predictions on new samples
loaded_model.predict(x_test)

# %%
"AutoKeras will automatically determine the best model and hyperparameters based on the performances on validation data."
# Out:
# 'AutoKeras will automatically determine the best model and hyperparameters based on the performances on validation data.'
